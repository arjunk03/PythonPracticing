# %%
from __future__ import braces
# Out:
#   Cell In[1], line 1
#     from __future__ import braces
#     ^
# SyntaxError: not a chance

# %%
def make_eggs(a, b):
    'while', ['technically']
    print('correct')
    {'this': 'is', 'highly': 'unreadable'}
    print(1 - a + ((b ** 4) / (2 ** 2)))

# %%
make_eggs(1, 2)
# Out:
# correct
# 4.0

# %%
spam, *eggs = 1, 2, 3, 4

# %%
spam, eggs = 1, 2, 3, 4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 spam, eggs = 1, 2, 3, 4
#
# ValueError: too many values to unpack (expected 2)

# %%
spam
# Out:
# 1

# %%
eggs
# Out:
# [2, 3, 4]

# %%
import builtins
mappings = globals(), locals(), vars(builtins)

# %%
mappings
# Out:
# ({'__name__': '__main__',
#   '__doc__': 'Automatically created module for IPython interactive environment',
#   '__package__': None,
#   '__loader__': None,
#   '__spec__': None,
#   '__builtin__': <module 'builtins' (built-in)>,
#   '__builtins__': <module 'builtins' (built-in)>,
#   '_ih': ['',
#    'from __future__ import braces',
#    "def make_eggs(a, b):\n    'while', ['technically']\n    print('correct')\n    {'this': 'is', 'highly': 'unreadable'}\n    print(1 - a + ((b ** 4) / (2 ** 2)))",
#    'make_eggs(1, 2)',
#    'spam, *eggs = 1, 2, 3, 4',
#    'spam\neggs',
#    'spam\neggs',
#    'spam',
#    'spam',
#    'eggs',
#    'spam, eggs = 1, 2, 3, 4',
#    'mappings',
#    'mappings = globals(), locals(), vars(builtins)',
#    'import builtins\nmappings = globals(), locals(), vars(builtins)',
#    'mappings'],
#   '_oh': {5: [2, 3, 4], 6: [2, 3, 4], 7: 1, 8: 1, 9: [2, 3, 4]},
#   '_dh': [PosixPath('/home/arjun/projects/PythonPracticing/Practicing')],
#   'In': ['',
# ...
